# %% [markdown]
# # Cleaning Datasets

# %%
import pandas as pd

# %%
df = pd.read_csv('car_sales_data.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %% [markdown]
# ### Remove Rows

# %%
new_df = df.dropna()
new_df
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit    percent
# 3  100000  16.666667
# 4  300000  50.000000
# 5  400000  66.666667
# 6  500000  83.333333

# %%
df.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %% [markdown]
# ##### inplace = True  changes in original dataframe

# %%
df2 = df.dropna(inplace=True)
df2

# %%
df
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit    percent
# 3  100000  16.666667
# 4  300000  50.000000
# 5  400000  66.666667
# 6  500000  83.333333

# %% [markdown]
# ## Replace Empty Values  [fillna]

# %%
df3 = pd.read_csv("car_sales_data.csv")

# %%
df3.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       7 non-null      int64
#  1   Name_of_company  7 non-null      object
#  2   Unit Cars        7 non-null      int64
#  3   car_sales        7 non-null      int64
#  4   prod_cost        7 non-null      int64
#  5   price            4 non-null      float64
#  6   profit           7 non-null      int64
#  7   percent          7 non-null      float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 576.0+ bytes

# %%
df4 = df3.fillna(10000)

# %%
df4
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000    10000.0
# 1           1        Mahindra      15000       9000     600000    10000.0
# 2           2           Tesla      20000      12000     600000    10000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
df5 = pd.read_csv('car_sales_data.csv')

# %%
df5
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000     6000.0     600000        NaN
# 1           1        Mahindra      15000     9000.0     600000        NaN
# 2           2           Tesla      20000        NaN     600000        NaN
# 3           3            Hero       7500     3500.0     600000   700000.0
# 4           4           Bajaj      10000     5000.0     600000   900000.0
# 5           5          Toyato      12000     6000.0     600000  1000000.0
# 6           6             BMW       8000     4000.0     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
df6 = df5.fillna(12000)

# %%
df6
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000     6000.0     600000    12000.0
# 1           1        Mahindra      15000     9000.0     600000    12000.0
# 2           2           Tesla      20000    12000.0     600000    12000.0
# 3           3            Hero       7500     3500.0     600000   700000.0
# 4           4           Bajaj      10000     5000.0     600000   900000.0
# 5           5          Toyato      12000     6000.0     600000  1000000.0
# 6           6             BMW       8000     4000.0     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
df7 = df5.copy()

# %%
df7
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000     6000.0     600000        NaN
# 1           1        Mahindra      15000     9000.0     600000        NaN
# 2           2           Tesla      20000        NaN     600000        NaN
# 3           3            Hero       7500     3500.0     600000   700000.0
# 4           4           Bajaj      10000     5000.0     600000   900000.0
# 5           5          Toyato      12000     6000.0     600000  1000000.0
# 6           6             BMW       8000     4000.0     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
df7['price'].fillna(100000, inplace=True)

# %%
df7
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000     6000.0     600000   100000.0
# 1           1        Mahindra      15000     9000.0     600000   100000.0
# 2           2           Tesla      20000        NaN     600000   100000.0
# 3           3            Hero       7500     3500.0     600000   700000.0
# 4           4           Bajaj      10000     5000.0     600000   900000.0
# 5           5          Toyato      12000     6000.0     600000  1000000.0
# 6           6             BMW       8000     4000.0     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %% [markdown]
# ## Replace Value using

# %% [markdown]
# 1. Mean (Average):
#     1. Average value (sum of all values divide by number of values(counts))
# 2. Median:
#     1. The value in middle of dataset[feature], after you have sorted all values ascending
# 3. Mode:
#     1. The most appear value in the dataset[feature]

# %% [markdown]
# ## 1. Mean

# %%
import pandas as pd

df = pd.read_csv('car_sales_data.csv')

x = df['price'].mean()

df['price'].fillna(x, inplace = True)

# %%
df.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000   925000.0
# 1           1        Mahindra      15000       9000     600000   925000.0
# 2           2           Tesla      20000      12000     600000   925000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
1100000 + 1000000.0 + 900000.0 + 700000.0
# Out:
# 3700000.0

# %%
3700000.0 / 4
# Out:
# 925000.0

# %% [markdown]
# ## 2. Median

# %%
import pandas as pd
df1 = pd.read_csv('car_sales_data.csv')

x = df1['price'].median()
print(x)
df1['price'].fillna(x, inplace=True)
# Out:
# 950000.0

# %%
df1
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000   950000.0
# 1           1        Mahindra      15000       9000     600000   950000.0
# 2           2           Tesla      20000      12000     600000   950000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %% [markdown]
# ## 3. Mode

# %%
import pandas as pd
df2 = pd.read_csv('car_sales_data.csv')
df2.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
x = df2['price'].mode()[0]
df2['price'].fillna(x, inplace = True)

# %%
df2
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000   700000.0
# 1           1        Mahindra      15000       9000     600000   700000.0
# 2           2           Tesla      20000      12000     600000   700000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000  1100000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
import pandas as pd
df3 = pd.read_csv('car_sales_data.csv')
df3.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000   800000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
x = df3['price'].mode()[0]
df3['price'].fillna(x, inplace = True)

# %%
df3
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000   700000.0
# 1           1        Mahindra      15000       9000     600000   700000.0
# 2           2           Tesla      20000      12000     600000   700000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000   800000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333

# %%
import pandas as pd
df4 = pd.read_csv('car_sales_data.csv')
df4.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000   800000.0
# 7           7          Toyato      12000       6000     600000        NaN
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333
# 7  400000   66.666667

# %%
x = df4['price'].mode()[0]
df4['price'].fillna(x, inplace = True)

# %%
df4
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000   700000.0
# 1           1        Mahindra      15000       9000     600000   700000.0
# 2           2           Tesla      20000      12000     600000   700000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000   800000.0
# 7           7          Toyato      12000       6000     600000   700000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333
# 7  400000   66.666667

# %% [markdown]
# # Drop Features

# %%
df5 = df4.drop(['Unnamed: 0'], axis=1)

# %%
df5
# Out:
#   Name_of_company  Unit Cars  car_sales  prod_cost      price  profit  \
# 0            Tata      10000       6000     600000   700000.0  200000
# 1        Mahindra      15000       9000     600000   700000.0  400000
# 2           Tesla      20000      12000     600000   700000.0  600000
# 3            Hero       7500       3500     600000   700000.0  100000
# 4           Bajaj      10000       5000     600000   900000.0  300000
# 5          Toyato      12000       6000     600000  1000000.0  400000
# 6             BMW       8000       4000     600000   800000.0  500000
# 7          Toyato      12000       6000     600000   700000.0  400000
#
#       percent
# 0   33.333333
# 1   66.666667
# 2  100.000000
# 3   16.666667
# 4   50.000000
# 5   66.666667
# 6   83.333333
# 7   66.666667

# %%
df5 = df4.drop(['Unnamed: 0','profit','percent'], axis=1)
df5
# Out:
#   Name_of_company  Unit Cars  car_sales  prod_cost      price
# 0            Tata      10000       6000     600000   700000.0
# 1        Mahindra      15000       9000     600000   700000.0
# 2           Tesla      20000      12000     600000   700000.0
# 3            Hero       7500       3500     600000   700000.0
# 4           Bajaj      10000       5000     600000   900000.0
# 5          Toyato      12000       6000     600000  1000000.0
# 6             BMW       8000       4000     600000   800000.0
# 7          Toyato      12000       6000     600000   700000.0

# %%
df4
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000   700000.0
# 1           1        Mahindra      15000       9000     600000   700000.0
# 2           2           Tesla      20000      12000     600000   700000.0
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000   800000.0
# 7           7          Toyato      12000       6000     600000   700000.0
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333
# 7  400000   66.666667

# %% [markdown]
# # Data Corelation

# %%
import pandas as pd
df6 = pd.read_csv('car_sales_data.csv')

# %%
df6.head(10)
# Out:
#    Unnamed: 0 Name_of_company  Unit Cars  car_sales  prod_cost      price  \
# 0           0            Tata      10000       6000     600000        NaN
# 1           1        Mahindra      15000       9000     600000        NaN
# 2           2           Tesla      20000      12000     600000        NaN
# 3           3            Hero       7500       3500     600000   700000.0
# 4           4           Bajaj      10000       5000     600000   900000.0
# 5           5          Toyato      12000       6000     600000  1000000.0
# 6           6             BMW       8000       4000     600000   800000.0
# 7           7          Toyato      12000       6000     600000        NaN
#
#    profit     percent
# 0  200000   33.333333
# 1  400000   66.666667
# 2  600000  100.000000
# 3  100000   16.666667
# 4  300000   50.000000
# 5  400000   66.666667
# 6  500000   83.333333
# 7  400000   66.666667

# %%
df6.shape
# Out:
# (8, 8)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       8 non-null      int64
#  1   Name_of_company  8 non-null      object
#  2   Unit Cars        8 non-null      int64
#  3   car_sales        8 non-null      int64
#  4   prod_cost        8 non-null      int64
#  5   price            4 non-null      float64
#  6   profit           8 non-null      int64
#  7   percent          8 non-null      float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 640.0+ bytes

# %%
df6.isnull()
# Out:
#    Unnamed: 0  Name_of_company  Unit Cars  car_sales  prod_cost  price  \
# 0       False            False      False      False      False   True
# 1       False            False      False      False      False   True
# 2       False            False      False      False      False   True
# 3       False            False      False      False      False  False
# 4       False            False      False      False      False  False
# 5       False            False      False      False      False  False
# 6       False            False      False      False      False  False
# 7       False            False      False      False      False   True
#
#    profit  percent
# 0   False    False
# 1   False    False
# 2   False    False
# 3   False    False
# 4   False    False
# 5   False    False
# 6   False    False
# 7   False    False

# %%
df6.isnull().sum()
# Out:
# Unnamed: 0         0
# Name_of_company    0
# Unit Cars          0
# car_sales          0
# prod_cost          0
# price              4
# profit             0
# percent            0
# dtype: int64

# %%
df6.describe()
# Out:
#        Unnamed: 0     Unit Cars     car_sales  prod_cost           price  \
# count     8.00000      8.000000      8.000000        8.0        4.000000
# mean      3.50000  11812.500000   6437.500000   600000.0   850000.000000
# std       2.44949   4087.764845   2795.883454        0.0   129099.444874
# min       0.00000   7500.000000   3500.000000   600000.0   700000.000000
# 25%       1.75000   9500.000000   4750.000000   600000.0   775000.000000
# 50%       3.50000  11000.000000   6000.000000   600000.0   850000.000000
# 75%       5.25000  12750.000000   6750.000000   600000.0   925000.000000
# max       7.00000  20000.000000  12000.000000   600000.0  1000000.000000
#
#               profit     percent
# count       8.000000    8.000000
# mean   362500.000000   60.416667
# std    159798.980866   26.633163
# min    100000.000000   16.666667
# 25%    275000.000000   45.833333
# 50%    400000.000000   66.666667
# 75%    425000.000000   70.833333
# max    600000.000000  100.000000

# %%
df7 = df6.drop(['Unnamed: 0'], axis = 1)

# %%
df7
# Out:
#   Name_of_company  Unit Cars  car_sales  prod_cost      price  profit  \
# 0            Tata      10000       6000     600000        NaN  200000
# 1        Mahindra      15000       9000     600000        NaN  400000
# 2           Tesla      20000      12000     600000        NaN  600000
# 3            Hero       7500       3500     600000   700000.0  100000
# 4           Bajaj      10000       5000     600000   900000.0  300000
# 5          Toyato      12000       6000     600000  1000000.0  400000
# 6             BMW       8000       4000     600000   800000.0  500000
# 7          Toyato      12000       6000     600000        NaN  400000
#
#       percent
# 0   33.333333
# 1   66.666667
# 2  100.000000
# 3   16.666667
# 4   50.000000
# 5   66.666667
# 6   83.333333
# 7   66.666667

# %%
x = df7['price'].mean()
print(x)
df7['price'].fillna(x, inplace=True)
# Out:
# 850000.0

# %%
df7
# Out:
#   Name_of_company  Unit Cars  car_sales  prod_cost      price  profit  \
# 0            Tata      10000       6000     600000   850000.0  200000
# 1        Mahindra      15000       9000     600000   850000.0  400000
# 2           Tesla      20000      12000     600000   850000.0  600000
# 3            Hero       7500       3500     600000   700000.0  100000
# 4           Bajaj      10000       5000     600000   900000.0  300000
# 5          Toyato      12000       6000     600000  1000000.0  400000
# 6             BMW       8000       4000     600000   800000.0  500000
# 7          Toyato      12000       6000     600000   850000.0  400000
#
#       percent
# 0   33.333333
# 1   66.666667
# 2  100.000000
# 3   16.666667
# 4   50.000000
# 5   66.666667
# 6   83.333333
# 7   66.666667

# %%
df8 = df7.drop(['prod_cost'],axis =1)

# %%
df8.corr()
# Out:
#            Unit Cars  car_sales     price    profit   percent
# Unit Cars   1.000000   0.986299  0.320466  0.676593  0.676593
# car_sales   0.986299   1.000000  0.256942  0.633502  0.633502
# price       0.320466   0.256942  1.000000  0.370220  0.370220
# profit      0.676593   0.633502  0.370220  1.000000  1.000000
# percent     0.676593   0.633502  0.370220  1.000000  1.000000

# %% [markdown]
# # Data Correlation

# %% [markdown]
# 1. Pandas Module corr()
# 2. The corr() method calculate relationship between each column[features] in your datasets
# 3. The corr() method ignores 'Non Numeric' columns
# 4. The Number(Result) varies from -1 to 1
# 5. The Result of corr() method is a table with a lot of numbers that represent, how strong relationship between two columns in Dataset
# 6. There are three types of Relationship Result:
#     1. Perfect Relationship
#     2. Good Relatinship
#     3. Bad Relationship

# %% [markdown]
# ## 1. Perfect Relationship

# %% [markdown]
# 1. 1 means that there is 1 to 1 relationship( a perfect Relationship)

# %% [markdown]
# ## 2. Good Relationship

# %% [markdown]
# 1. 0.9 is also good relationship, if you increase value [0.6 to close 1]
# 2. -0.9 is also good relationship, if you increase value [0.6 to close 1]

# %% [markdown]
# ## 3.  Bad Relationship

# %% [markdown]
# 1. Value less than 0.5

# %% [markdown]
# ## What is Good Relationship?

# %% [markdown]
# Atleast (0.6) or (-0.6) above it is a good relationship
