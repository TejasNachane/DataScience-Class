# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Dataset

# %%
df = pd.read_csv('autos_dataset.csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ## DataTypes

# %% [markdown]
# 1. Data has different types of data
# 2. Pandas dataframes are store:
#     1. Object
#     2. int
#     3. float
#     4. bool
#     5. datetime
# 3. In each and every columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe(include='all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
# df.info()

# %% [markdown]
# ## Data PreProcessing

# %% [markdown]
# 1. Steps for working missing data:
#     1. Identify missing data
#     2. Deal with missing data
#     3. Correct data format

# %% [markdown]
# #### 2. Identify missing data

# %% [markdown]
# 1. In the autos dataset, missing data comes with '?'
# 2. Replace '?' with NaN (Not a Number)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.replace('?',np.nan, inplace= True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# ### Evaluation of Missing Data

# %% [markdown]
# #### 1. .isnull()
# #### 2. .notnull()

# %%
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %% [markdown]
# ## Deal with Missing Data

# %% [markdown]
# 1. Drop Data:
#     1. Drop the Whole row
#     2. Drop the whole column
#
# 2. Replace Data:
#     1. replace mean
#     2. replace mode [freqency]
#     3. replace by median
#     4. replace if based on the other function

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# 1. normalized-losses    41
# 2. num-of-doors          2
# 3. bore                  4
# 4. stroke                4
# 5. horsepower            2
# 6. peak-rpm              2
# 7. price                 4

# %%
df['normalized-losses'] = df['normalized-losses'].astype('float64')
# df['num-of-doors'] = df['num-of-doors'].astype('float64').mean(axis = 0)
df['bore'] = df['bore'].astype('float64')
df['stroke'] = df['stroke'].astype('float64')
df['horsepower'] = df['horsepower'].astype('float64')
df['peak-rpm'] = df['peak-rpm'].astype('float64')
df['price'] = df['price'].astype('float64')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df = df.drop(['normalized-losses','num-of-doors','drive-wheels','engine-location','fuel-system','engine-type'], axis= 1)

# %%
# df.info()

# %%
df = df.drop(['make','fuel-type','aspiration','body-style'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   wheel-base         205 non-null    float64
#  2   length             205 non-null    float64
#  3   width              205 non-null    float64
#  4   height             205 non-null    float64
#  5   curb-weight        205 non-null    int64
#  6   num-of-cylinders   205 non-null    object
#  7   engine-size        205 non-null    int64
#  8   bore               201 non-null    float64
#  9   stroke             201 non-null    float64
#  10  compression-ratio  205 non-null    float64
#  11  horsepower         203 non-null    float64
#  12  peak-rpm           203 non-null    float64
#  13  city-mpg           205 non-null    int64
#  14  highway-mpg        205 non-null    int64
#  15  price              201 non-null    float64
# ...

# %%
df.head()
# Out:
#    symboling  wheel-base  length  width  height  curb-weight num-of-cylinders  \
# 0          3        88.6   168.8   64.1    48.8         2548             four
# 1          3        88.6   168.8   64.1    48.8         2548             four
# 2          1        94.5   171.2   65.5    52.4         2823              six
# 3          2        99.8   176.6   66.2    54.3         2337             four
# 4          2        99.4   176.6   66.4    54.3         2824             five
#
#    engine-size  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0          130  3.47    2.68                9.0       111.0    5000.0
# 1          130  3.47    2.68                9.0       111.0    5000.0
# 2          152  2.68    3.47                9.0       154.0    5000.0
# 3          109  3.19    3.40               10.0       102.0    5500.0
# 4          136  3.19    3.40                8.0       115.0    5500.0
#
#    city-mpg  highway-mpg    price
# 0        21           27  13495.0
# ...

# %%
df['num-of-cylinders']
# Out:
# 0      four
# 1      four
# 2       six
# 3      four
# 4      five
#        ...
# 200    four
# 201    four
# 202     six
# 203     six
# 204    four
# Name: num-of-cylinders, Length: 205, dtype: object

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df['num-of-cylinders'] = df['num-of-cylinders'].replace({'one':1, 'two':2,'three':3, 'four':4,'five':5, 'six':6,'seven':7, 
                                                          'eight':8, 'nine':9, 'ten':10, 'eleven':11, 'twelve':12})

# %%
df['num-of-cylinders']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 200    4
# 201    4
# 202    6
# 203    6
# 204    4
# Name: num-of-cylinders, Length: 205, dtype: int64

# %%
df.head()
# Out:
#    symboling  wheel-base  length  width  height  curb-weight  \
# 0          3        88.6   168.8   64.1    48.8         2548
# 1          3        88.6   168.8   64.1    48.8         2548
# 2          1        94.5   171.2   65.5    52.4         2823
# 3          2        99.8   176.6   66.2    54.3         2337
# 4          2        99.4   176.6   66.4    54.3         2824
#
#    num-of-cylinders  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0                 4          130  3.47    2.68                9.0       111.0
# 1                 4          130  3.47    2.68                9.0       111.0
# 2                 6          152  2.68    3.47                9.0       154.0
# 3                 4          109  3.19    3.40               10.0       102.0
# 4                 5          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price
# 0    5000.0        21           27  13495.0
# ...

# %%
df['horsepower'].unique()
# Out:
# array([111., 154., 102., 115., 110., 140., 160., 101., 121., 182.,  48.,
#         70.,  68.,  88., 145.,  58.,  76.,  60.,  86., 100.,  78.,  90.,
#        176., 262., 135.,  84.,  64., 120.,  72., 123., 155., 184., 175.,
#        116.,  69.,  55.,  97., 152., 200.,  95., 142., 143., 207., 288.,
#         nan,  73.,  82.,  94.,  62.,  56., 112.,  92., 161., 156.,  52.,
#         85., 114., 162., 134., 106.])

# %%
df.isnull().sum()
# Out:
# symboling            0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# num-of-cylinders     0
# engine-size          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %% [markdown]
# ### Missing Data Handled [fill using Mean value]

# %%
df['bore'] = df['bore'].fillna(df['bore'].mean())
df['stroke'] = df['stroke'].fillna(df['stroke'].mean())
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())
df['peak-rpm'] = df['peak-rpm'].fillna(df['peak-rpm'].mean())
df['price'] = df['price'].fillna(df['price'].mean())

# %%
# df.isnull().sum()
df.head()
# Out:
#    symboling  wheel-base  length  width  height  curb-weight  \
# 0          3        88.6   168.8   64.1    48.8         2548
# 1          3        88.6   168.8   64.1    48.8         2548
# 2          1        94.5   171.2   65.5    52.4         2823
# 3          2        99.8   176.6   66.2    54.3         2337
# 4          2        99.4   176.6   66.4    54.3         2824
#
#    num-of-cylinders  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0                 4          130  3.47    2.68                9.0       111.0
# 1                 4          130  3.47    2.68                9.0       111.0
# 2                 6          152  2.68    3.47                9.0       154.0
# 3                 4          109  3.19    3.40               10.0       102.0
# 4                 5          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price
# 0    5000.0        21           27  13495.0
# ...

# %%
df.describe().T
# Out:
#                    count          mean          std      min      25%  \
# symboling          205.0      0.834146     1.245307    -2.00     0.00
# wheel-base         205.0     98.756585     6.021776    86.60    94.50
# length             205.0    174.049268    12.337289   141.10   166.30
# width              205.0     65.907805     2.145204    60.30    64.10
# height             205.0     53.724878     2.443522    47.80    52.00
# curb-weight        205.0   2555.565854   520.680204  1488.00  2145.00
# num-of-cylinders   205.0      4.380488     1.080854     2.00     4.00
# engine-size        205.0    126.907317    41.642693    61.00    97.00
# bore               205.0      3.329751     0.270844     2.54     3.15
# stroke             205.0      3.255423     0.313597     2.07     3.11
# compression-ratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower         205.0    104.256158    39.519211    48.00    70.00
# ...

# %%
df.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# num-of-cylinders   -0.113129    0.339507  0.430672  0.545007 -0.013995
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# bore               -0.130083    0.488760  0.606462  0.559152  0.171101
# stroke             -0.008689    0.160944  0.129522  0.182939 -0.055351
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# horsepower          0.071389    0.351957  0.554434  0.642195 -0.110137
# ...

# %% [markdown]
# # EDA [Exploratary Data Analysis]

# %%
sns.countplot(x = 'horsepower', data = df)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='count'>

# %%
plt.hist(df['horsepower'])
plt.title('Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df['horsepower'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df[['bore','stroke','compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055909           0.005201    0.575737
# stroke            -0.055909  1.000000           0.186105    0.088264
# compression-ratio  0.005201  0.186105           1.000000   -0.205740
# horsepower         0.575737  0.088264          -0.205740    1.000000

# %% [markdown]
# ## Contineuos Numerical Data

# %%
sns.regplot(x ='engine-size', y = 'price', data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.861752
# price           0.861752  1.000000

# %%
sns.regplot(x ='symboling',y ='price', data=df)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %%
df[['symboling','price']].corr()
# Out:
#            symboling     price
# symboling   1.000000 -0.082201
# price      -0.082201  1.000000

# %%
sns.regplot(x = 'highway-mpg', y = 'price',data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# ### Weak Relationship

# %%
sns.regplot(x = 'peak-rpm',y ='price',data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.100854
# price    -0.100854  1.000000

# %%
sns.boxplot(x ='num-of-cylinders' ,y = 'price', data =df)
# Out:
# <AxesSubplot:xlabel='num-of-cylinders', ylabel='price'>

# %% [markdown]
# ### Indepdendent variable[x] and Dependent Variable [y]

# %%
# Independent Variable
x = df.drop('price',axis=1)

# %%
x.head()
# Out:
#    symboling  wheel-base  length  width  height  curb-weight  \
# 0          3        88.6   168.8   64.1    48.8         2548
# 1          3        88.6   168.8   64.1    48.8         2548
# 2          1        94.5   171.2   65.5    52.4         2823
# 3          2        99.8   176.6   66.2    54.3         2337
# 4          2        99.4   176.6   66.4    54.3         2824
#
#    num-of-cylinders  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0                 4          130  3.47    2.68                9.0       111.0
# 1                 4          130  3.47    2.68                9.0       111.0
# 2                 6          152  2.68    3.47                9.0       154.0
# 3                 4          109  3.19    3.40               10.0       102.0
# 4                 5          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg
# 0    5000.0        21           27
# 1    5000.0        21           27
# ...

# %%
#Dependent Variable
y = df['price']

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
# spliting data into training and test (i.e. 80% - train & 20% - test)

# %%
x_test.shape
# Out:
# (41, 15)

# %%
y_test.shape
# Out:
# (41,)

# %%
x_train.shape
# Out:
# (164, 15)

# %%
y_train.shape
# Out:
# (164,)

# %% [markdown]
# ### The data is non-normalize

# %%
linear_regression = LinearRegression()

# %%
print(linear_regression)
# Out:
# LinearRegression()

# %%
linear_regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# *The data training is finished.*

# %% [markdown]
# **Now we need to test the data:**

# %%
# we predict by using the x_test data

y_pred = linear_regression.predict(x_test)

# %%
print(y_pred[:3])
# Out:
# [ 9114.84427919 21253.26829085 14527.14797849]

# %%
print(y_test[:3])
# Out:
# 177    11248.0
# 105    19699.0
# 170    11199.0
# Name: price, dtype: float64

# %%
m_values = linear_regression.coef_
print(m_values)
# Out:
# [ 2.71144505e+01  8.59130393e+01 -2.80177211e+01  4.69619397e+02
#   2.00519980e+02 -1.07019707e+00 -3.14454434e+03  2.40518870e+02
#  -5.74587891e+03 -5.33777023e+03  3.14051370e+02  1.22630116e+01
#   2.79026697e+00 -1.11464926e+02 -1.77714088e+01]

# %%
intercept = linear_regression.intercept_
print(intercept)
# Out:
# -24994.683231702

# %% [markdown]
# ### Now we consider data as normalize

# %%
model = LinearRegression(normalize= True)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
model.coef_
# Out:
# array([ 2.71144505e+01,  8.59130393e+01, -2.80177211e+01,  4.69619397e+02,
#         2.00519980e+02, -1.07019707e+00, -3.14454434e+03,  2.40518870e+02,
#        -5.74587891e+03, -5.33777023e+03,  3.14051370e+02,  1.22630116e+01,
#         2.79026697e+00, -1.11464926e+02, -1.77714088e+01])

# %%
model.intercept_
# Out:
# -24994.68323170254

# %%
model.predict(x_test)
# Out:
# array([ 9114.84427919, 21253.26829085, 14527.14797849,  7809.45176791,
#        14675.90537087, 10802.0337635 ,  9735.44011933,  6276.58610175,
#         6115.79554868, 17559.70951419, 18577.18778045, 45116.88258433,
#        18619.78000697, 11124.29237108, 10848.24303033, 17679.73601666,
#           60.02176611, 13914.26969041, 13576.98951887, 11140.34532709,
#        13855.4088517 , 26435.90421045, 10956.87619587, 10250.50455556,
#        14894.53199714, 17386.43017631,  6437.67700128, 24995.47108974,
#         6579.7107577 , 10833.27874076,  9458.68238444, 10655.67834102,
#         9410.59984649,  6418.67449313, 13887.34070233,  6350.21047836,
#        10167.12269097, 10132.93343549,  6178.17680683,  6951.35312437,
#        10092.04904343])

# %%
new_pred = model.predict(x_test)

# %%
#Error = Actual - Predicted

pd.DataFrame({"Actual_value":y_test, "New_Prediction":new_pred, "Error": y_test - new_pred})
# Out:
#      Actual_value  New_Prediction        Error
# 177       11248.0     9114.844279  2133.155721
# 105       19699.0    21253.268291 -1554.268291
# 170       11199.0    14527.147978 -3328.147978
# 119        7957.0     7809.451768   147.548232
# 167        8449.0    14675.905371 -6226.905371
# 131        9895.0    10802.033764  -907.033764
# 184        7995.0     9735.440119 -1740.440119
# 95         7799.0     6276.586102  1522.413898
# 155        8778.0     6115.795549  2662.204451
# 197       16515.0    17559.709514 -1044.709514
# 200       16845.0    18577.187780 -1732.187780
# 73        40960.0    45116.882584 -4156.882584
# 116       17950.0    18619.780007  -669.780007
# 64        11245.0    11124.292371   120.707629
# 147       10198.0    10848.243030  -650.243030
# 195       13415.0    17679.736017 -4264.736017
# 18         5151.0       60.021766  5090.978234
# 107       11900.0    13914.269690 -2014.269690
# 63        10795.0    13576.989519 -2781.989519
# ...

# %%
train_score = model.score(x_train, y_train)

# %%
print(train_score * 100)
# Out:
# 81.76098903255799

# %%
# test_score = model.score(x_test, new_pred)

# %%
# print(test_score * 100)

# %%
test_score = model.score(x_test, y_test)

# %%
print(test_score * 100)
# Out:
# 87.22121593273754

# %% [raw]
# Accuracy:
#     <49 = Bad Accuracy
#     >50 close to 100 - Good Accuracy

# %%
#Error = Actual - Predicted

pd.DataFrame({"Actual_value":y_test, "New_Prediction":y_pred, "Error": y_test - y_pred})
# Out:
#      Actual_value  New_Prediction        Error
# 177       11248.0     9114.844279  2133.155721
# 105       19699.0    21253.268291 -1554.268291
# 170       11199.0    14527.147978 -3328.147978
# 119        7957.0     7809.451768   147.548232
# 167        8449.0    14675.905371 -6226.905371
# 131        9895.0    10802.033764  -907.033764
# 184        7995.0     9735.440119 -1740.440119
# 95         7799.0     6276.586102  1522.413898
# 155        8778.0     6115.795549  2662.204451
# 197       16515.0    17559.709514 -1044.709514
# 200       16845.0    18577.187780 -1732.187780
# 73        40960.0    45116.882584 -4156.882584
# 116       17950.0    18619.780007  -669.780007
# 64        11245.0    11124.292371   120.707629
# 147       10198.0    10848.243030  -650.243030
# 195       13415.0    17679.736017 -4264.736017
# 18         5151.0       60.021766  5090.978234
# 107       11900.0    13914.269690 -2014.269690
# 63        10795.0    13576.989519 -2781.989519
# ...
